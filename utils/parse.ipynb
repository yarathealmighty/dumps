# %%
# %pip install pandas lxml
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\stali\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (2.2.2)
# Requirement already satisfied: lxml in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (5.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from lxml import etree
from collections import defaultdict
import re

# %%
def clean_html(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

def read_posts(file_path):
  d = defaultdict(list)

  doc = etree.parse(file_path)

  rows = doc.xpath('.//row')

  for r in rows:
    d['Id'].append(r.get('Id'))
    d['PostTypeId'].append(r.get('PostTypeId'))
    d['AcceptedAnswerId'].append(r.get('AcceptedAnswerId'))
    d['CreationDate'].append(r.get('CreationDate'))
    d['Score'].append(r.get('Score'))
    d['ViewCount'].append(r.get('ViewCount'))

    #for human readiblity
    raw_body_text = r.get('Body')
    clean_body_text = clean_html(raw_body_text)
    d['Body'].append(clean_body_text)

    d['OwnerUserId'].append(r.get('OwnerUserId'))
    d['LastActivityDate'].append(r.get('LastActivityDate'))
    d['Title'].append(r.get('Title'))
    d['Tags'].append(r.get('Tags'))
    d['AnswerCount'].append(r.get('AnswerCount'))
    d['CommentCount'].append(r.get('CommentCount'))
    d['ContentLicense'].append(r.get('ContentLicense'))

  df = pd.DataFrame(d)
  return df

# %%
FILENAME = 'Posts.xml'

df = read_posts(FILENAME)
df.to_csv('beer.csv', index=False)
df
# Out:
#         Id PostTypeId AcceptedAnswerId             CreationDate Score  \
# 0        1          1                4  2014-01-21T20:26:05.383    21
# 1        2          1              175  2014-01-21T20:27:29.797    25
# 2        3          1               13  2014-01-21T20:30:17.437    22
# 3        4          2             None  2014-01-21T20:31:18.540    15
# 4        5          1               19  2014-01-21T20:31:44.693    22
# ...    ...        ...              ...                      ...   ...
# 3919  9665          1             None  2024-02-18T22:30:37.663     1
# 3920  9667          1             None  2024-03-08T15:35:22.687     0
# 3921  9668          1             None  2024-03-09T23:24:39.277     0
# 3922  9670          2             None  2024-03-13T15:38:01.607     0
# 3923  9671          2             None  2024-03-13T21:42:37.643    -1
#
#      ViewCount                                               Body OwnerUserId  \
# 0         2461  I was offered a beer the other day that was re...           7
# 1         3205  As far as we know, when did humans first brew ...           7
# 2          546  How is low/no alcohol beer made? I'm assuming ...           7
# 3         None  Citra is a registered trademark since 2007. Ci...          12
# 4         4171  In general, what's the best way to work out th...           7
# ...        ...                                                ...         ...
# 3919        47  I made a 5 gallon batch of mead, I racked it o...       15707
# 3920        49  I'm looking for a wine API with basic info (pr...       16733
# 3921        24  I found an old bottle of Gin my parents had.  ...       16735
# 3922      None  There is an API for Vivino. Although I'm not s...        8518
# 3923      None  Well, I mean, its different for everyone, righ...       16744
#
#              LastActivityDate  \
# 0     2014-01-21T22:04:34.977
# 1     2014-01-23T01:55:21.853
# 2     2015-01-29T14:50:56.627
# 3     2014-01-21T21:36:38.133
# 4     2017-06-07T11:10:28.887
# ...                       ...
# 3919  2024-03-04T12:21:53.203
# 3920  2024-03-13T15:38:01.607
# 3921  2024-03-09T23:24:39.277
# 3922  2024-03-13T15:38:01.607
# 3923  2024-03-13T21:42:37.643
#
#                                                   Title  \
# 0     What is a citra hop, and how does it differ fr...
# 1                  When was the first beer ever brewed?
# 2                   How is reduced alcoholic beer made?
# 3                                                  None
# 4              What temperature should I serve my beer?
# ...                                                 ...
# 3919             Mead left for years; is it still good?
# 3920         Where can I find open APIs with wine data?
# 3921                   Beefeater gin - unique bottle id
# 3922                                               None
# 3923                                               None
#
#                               Tags AnswerCount CommentCount ContentLicense
# 0                           |hops|           1            0   CC BY-SA 3.0
# 1                        |history|           4            3   CC BY-SA 3.0
# 2                        |brewing|           3            0   CC BY-SA 3.0
# 3                             None        None            0   CC BY-SA 3.0
# 4            |serving|temperature|           4            9   CC BY-SA 3.0
# ...                            ...         ...          ...            ...
# 3919                        |mead|           0            2   CC BY-SA 4.0
# 3920                        |wine|           1            0   CC BY-SA 4.0
# 3921  |bottles|gin|identification|           0            0   CC BY-SA 4.0
# 3922                          None        None            0   CC BY-SA 4.0
# 3923                          None        None            1   CC BY-SA 4.0
#
# [3924 rows x 14 columns]

# %%
# Out:
# Id                                                                  1
# PostTypeId                                                          1
# AcceptedAnswerId                                                   24
# CreationDate                                  2015-01-27T20:09:32.720
# Score                                                              49
# ViewCount                                                        3045
# Body                I just got a pound of microroasted, local coff...
# OwnerUserId                                                         4
# LastActivityDate                              2019-02-04T13:15:48.970
# Title                           How should I store whole bean coffee?
# Tags                                             |storage|whole-bean|
# AnswerCount                                                         7
# CommentCount                                                        4
# ContentLicense                                           CC BY-SA 3.0
# Name: 0, dtype: object
