# %%
# %pip install pandas lxml
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\stali\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (2.2.2)
# Requirement already satisfied: lxml in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (5.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\stali\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from lxml import etree
from collections import defaultdict
import re

# %%
def clean_html(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

def read_posts(file_path):
  d = defaultdict(list)

  doc = etree.parse(file_path)

  rows = doc.xpath('.//row')

  for r in rows:
    d['Id'].append(r.get('Id'))
    d['PostTypeId'].append(r.get('PostTypeId'))
    d['ParentId'].append(r.get('ParentId'))
    d['AcceptedAnswerId'].append(r.get('AcceptedAnswerId'))
    d['CreationDate'].append(r.get('CreationDate'))
    d['Score'].append(r.get('Score'))
    d['ViewCount'].append(r.get('ViewCount'))

    #for human readiblity
    raw_body_text = r.get('Body')
    clean_body_text = clean_html(raw_body_text)
    d['Body'].append(clean_body_text)

    d['OwnerUserId'].append(r.get('OwnerUserId'))
    d['LastActivityDate'].append(r.get('LastActivityDate'))
    d['Title'].append(r.get('Title'))
    d['Tags'].append(r.get('Tags'))
    d['AnswerCount'].append(r.get('AnswerCount'))
    d['CommentCount'].append(r.get('CommentCount'))
    d['ContentLicense'].append(r.get('ContentLicense'))

  df = pd.DataFrame(d)
  return df

# %%
FILENAME = 'Posts.xml'

df = read_posts(FILENAME)
df.to_csv('movies.csv', index=False)
df
# Out:
#            Id PostTypeId ParentId AcceptedAnswerId             CreationDate  \
# 0           1          1     None             2776  2011-11-30T19:15:54.070
# 1           2          2        1             None  2011-11-30T19:37:10.510
# 2           3          1     None              814  2011-11-30T19:41:14.960
# 3           4          1     None              120  2011-11-30T19:42:45.470
# 4           6          1     None               21  2011-11-30T19:44:55.593
# ...       ...        ...      ...              ...                      ...
# 65064  122376          2   122375             None  2024-03-30T07:27:16.777
# 65065  122377          2   122375             None  2024-03-30T10:07:04.903
# 65066  122378          2    35443             None  2024-03-30T18:05:33.640
# 65067  122379          2   106705             None  2024-03-30T20:37:24.103
# 65068  122380          2   113254             None  2024-03-31T14:29:34.700
#
#       Score ViewCount                                               Body  \
# 0        32      8718  Some comedians / actors are given creative fre...
# 1        15      None  According to the trivia on IMDb, Owen Wilson a...
# 2        29      1970  In his Star Wars Episode 1 review/analysis, Mi...
# 3        59      4271  I'm a big fan of the Pink Panther movies (the ...
# 4        16      8476  At the end of the movie, adult Jack (Sean Penn...
# ...     ...       ...                                                ...
# 65064    23      None  The atomics are not used on the city, they are...
# 65065    11      None  According to the follow-up novel (set shortly ...
# 65066     1      None  According to the official novelisation for Kin...
# 65067    -1      None  I think one of the often unmentioned motivatio...
# 65068    -1      None  The painting was a Van Gogh worth over $100 mi...
#
#       OwnerUserId         LastActivityDate  \
# 0              11  2022-02-12T21:59:39.633
# 1              31  2011-11-30T19:37:10.510
# 2              41  2019-05-15T02:23:45.307
# 3              22  2020-11-18T17:05:17.490
# 4              34  2013-06-06T20:02:04.800
# ...           ...                      ...
# 65064       34317  2024-03-31T10:49:53.613
# 65065      100979  2024-03-30T10:13:26.453
# 65066      100979  2024-03-30T18:05:33.640
# 65067      104067  2024-03-30T20:47:03.847
# 65068      104073  2024-03-31T15:07:50.833
#
#                                                    Title  \
# 0      To what extent were the actors in Wedding Cras...
# 1                                                   None
# 2          Evaluating characters by means of description
# 3      Was the original "Pink Panther" movie intended...
# 4         What does the ending of The Tree of Life mean?
# ...                                                  ...
# 65064                                               None
# 65065                                               None
# 65066                                               None
# 65067                                               None
# 65068                                               None
#
#                                                     Tags AnswerCount  \
# 0                                     |wedding-crashers|           2
# 1                                                   None        None
# 2                                   |analysis|star-wars|           2
# 3                              |comedy|the-pink-panther|           5
# 4      |plot-explanation|analysis|ending|the-tree-of-...           2
# ...                                                  ...         ...
# 65064                                               None        None
# 65065                                               None        None
# 65066                                               None        None
# 65067                                               None        None
# 65068                                               None        None
#
#       CommentCount ContentLicense
# 0                0   CC BY-SA 4.0
# 1                3   CC BY-SA 3.0
# 2                2   CC BY-SA 4.0
# 3                2   CC BY-SA 3.0
# 4                0   CC BY-SA 3.0
# ...            ...            ...
# 65064            3   CC BY-SA 4.0
# 65065            1   CC BY-SA 4.0
# 65066            0   CC BY-SA 4.0
# 65067            2   CC BY-SA 4.0
# 65068            1   CC BY-SA 4.0
#
# [65069 rows x 15 columns]

# %%
# Out:
# Id                                                                  1
# PostTypeId                                                          1
# AcceptedAnswerId                                                   24
# CreationDate                                  2015-01-27T20:09:32.720
# Score                                                              49
# ViewCount                                                        3045
# Body                I just got a pound of microroasted, local coff...
# OwnerUserId                                                         4
# LastActivityDate                              2019-02-04T13:15:48.970
# Title                           How should I store whole bean coffee?
# Tags                                             |storage|whole-bean|
# AnswerCount                                                         7
# CommentCount                                                        4
# ContentLicense                                           CC BY-SA 3.0
# Name: 0, dtype: object
